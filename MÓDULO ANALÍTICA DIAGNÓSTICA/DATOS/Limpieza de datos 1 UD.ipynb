# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import glob

# %%
ruta_archivo = '/content/plantatotal.txt'
industrial = pd.read_csv(ruta_archivo, sep='|', encoding='latin1')
industrial
# Out:
#               Regional               Zonal      Provincia    Oficina  \
# 0               Bogota        Zonal Bogota         Bogota     Bogota
# 1               Bogota        Zonal Bogota         Bogota     Bogota
# 2               Bogota        Zonal Bogota         Bogota     Bogota
# 3               Bogota        Zonal Bogota         Bogota     Bogota
# 4               Bogota        Zonal Bogota         Bogota     Bogota
# ...                ...                 ...            ...        ...
# 5666            Bogota  Zonal Cundinamarca  Sabana Centro  Zipaquira
# 5667     CentroOriente        Zonal Boyaca        Tundama    Duitama
# 5668     CentroOriente        Zonal Boyaca       Sugamuxi   Sogamoso
# 5669     CentroOriente        Zonal Boyaca         Centro      Tunja
# 5670  Zonas Especiales      Zonal Casanare     Piedemonte      Yopal
#
#      Oficina_Base Clave_GC          Nombre_Gerente_Comercial Clave_CC  \
# ...
